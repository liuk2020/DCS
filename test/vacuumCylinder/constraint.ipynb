# %%
import matplotlib.pyplot as plt
import numpy as np
try:
    import matplotlib
    matplotlib.rcParams['text.usetex'] = True
except:
    pass

# %%
from dcs.boozerForm import BoozerForm

boozerlib = BoozerForm() 
boozerlib.verbose = False
boozerlib.read_boozmn("../datas/boozer_wout_LandremanPaul2021_QA.nc") 
surfBoozer = boozerlib.surface() 

_ = surfBoozer.plot_plt()

# %%
print(boozerlib.bmnc_b)
# Out:
# [[ 1.00651874e+00  1.00649731e+00  1.00647276e+00 ...  1.00072100e+00
#    1.00069103e+00  1.00066107e+00]
#  [ 4.40817285e-05  4.58331435e-05  4.54298545e-05 ... -3.12832350e-06
#   -2.95902287e-06 -2.78545787e-06]
#  [ 1.44750015e-05  1.29018930e-05  1.24161437e-05 ... -1.12604278e-05
#   -1.15623275e-05 -1.18671425e-05]
#  ...
#  [ 4.10495883e-16  2.84699124e-15  1.42442583e-14 ... -6.19393114e-14
#   -5.16444052e-14 -4.07983787e-14]
#  [-1.31239285e-16  2.81538844e-15  1.74931955e-15 ... -6.82427662e-14
#   -5.58416110e-14 -4.23827792e-14]
#  [-2.78755155e-16 -4.19069889e-15 -8.53677074e-15 ... -6.89043811e-14
#   -6.42170279e-14 -5.91209981e-14]]
